# %%
import functions
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
_, movie_by_user, movie_ratings, user_ratings = functions.analysing_dataframes('ml-latest-small\.'.replace('.',''), show = True)
# Out:
# How many reviews are we dealing with?  100004
# And how many movies?  9125
# Genre's correlation:
#                  media_Drama  media_Comedy  media_Action  media_Thriller  \
# media_Drama         1.000000      0.697513      0.609334        0.697694
# media_Comedy        0.697513      1.000000      0.641474        0.615499
# media_Action        0.609334      0.641474      1.000000        0.764011
# media_Thriller      0.697694      0.615499      0.764011        1.000000
# media_Adventure     0.640897      0.680507      0.777698        0.632715
# media_Romance       0.704835      0.762898      0.542753        0.565676
# media_Crime         0.685143      0.573498      0.584300        0.722991
# media_SciFi         0.544054      0.542868      0.769571        0.685652
#
#                  media_Adventure  media_Romance  media_Crime  media_SciFi
# media_Drama             0.640897       0.704835     0.685143     0.544054
# ...

# %% [markdown]
# #### The average of each genre for each user was calculated as a weighted rating average, with its weight as the count of movies for that genre the user has rated divided by total number of movies the user has rated.

# %%
print("Each genre's rating for every user:\n")
user_ratings
# Out:
# Each genre's rating for every user:
#         media_Drama  media_Comedy  media_Action  media_Thriller  \
# userId
# 1.0            2.57          2.00          2.80            2.83
# 2.0            3.62          3.09          3.32            3.33
# 3.0            3.92          3.61          3.47            3.55
# 4.0            4.46          4.33          4.27            4.02
# 5.0            3.81          3.98          4.00            3.62
# ...             ...           ...           ...             ...
# 667.0          3.71          3.88          3.27            3.50
# 668.0          4.31          3.44          3.50            4.50
# 669.0          3.42          3.40          3.78            3.08
# 670.0          3.76          3.86          3.60            3.90
# 671.0          3.78          3.81          4.00            4.05
#
#         media_Adventure  media_Romance  media_Crime  media_Sci-Fi
# userId
# 1.0                2.17           3.50         2.50          2.40
# ...

# %%
number = 215
df = functions.recommendation(number, movie_by_user, movie_ratings, user_ratings)
# Out:
# Out of 8982 movies, 913 fits the user's taste.
# From users with similar taste, 297 movies were found to be greatly enjoyed by a lot of them.
# <table>
#   <tr>
#     <th>Movies you'll probably enjoy:</th>
#     <th>Movies you'll definitely enjoy:</th>
#   </tr>
# <tr>
#         <td>12 Angry Men (1957)</td>
#         <td>'night Mother (1986)</td>
#       </tr>
# <tr>
#         <td>12 Angry Men (1997)</td>
#         <td>10 Attitudes (2001)</td>
#       </tr>
# <tr>
#         <td>1984 (1956)</td>
#         <td>16 Wishes (2010)</td>
#       </tr>
# <tr>
#         <td>21 Up (1977)</td>
#         <td>29th and Gay (2005)</td>
#       </tr>
# <tr>
#         <td>23 (23 - Nichts ist so wie es scheint) (1998)</td>
#         <td>3 Women (Three Women) (1977)</td>
#       </tr>
# <tr>
#         <td>28 Up (1985)</td>
#         <td>Above the Law (1988)</td>
#       </tr>
# <tr>
#         <td>35 Up (1991)</td>
#         <td>Absolute Giganten (1999)</td>
#       </tr>
# <tr>
# ...
